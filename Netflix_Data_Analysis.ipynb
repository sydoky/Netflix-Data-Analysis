# %% [markdown]
# <a href="https://colab.research.google.com/github/sydoky/Netflix-Data-Analysis/blob/main/Netflix_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import plotly.express as px
from textblob import TextBlob #For sentiment Analysis

df=pd.read_csv("/content/netflix_titles.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # **Let's look at the distribution of content ratings on Netflix**

# %%
z=df.groupby("rating").size().reset_index(name="counts")
pieChart=px.pie(z,values="counts",names="rating",title="Distribution of contents Ratinng on Netflix",
                color_discrete_sequence=px.colors.qualitative.Set3) 
pieChart.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
z=df.groupby("director").size().reset_index(name="counts")
z
# Out:
#                  director  counts
# 0             A. L. Vijay       2
# 1            A. Raajdheep       1
# 2               A. Salaam       1
# 3         A.R. Murugadoss       2
# 4         Aadish Keluskar       1
# ...                   ...     ...
# 4523          Çagan Irmak       1
# 4524     Ísold Uggadóttir       1
# 4525  Óskar Thór Axelsson       1
# 4526     Ömer Faruk Sorak       2
# 4527         Şenol Sönmez       2
#
# [4528 rows x 2 columns]

# %% [markdown]
# # **Top 5 Directors:**

# %%
df["director"].isna().sum()
# Out:
# 2634

# %%
df["director"]=df["director"].fillna("No Director Specified")
df
# Out:
#      show_id     type                  title               director  \
# 0         s1    Movie   Dick Johnson Is Dead        Kirsten Johnson
# 1         s2  TV Show          Blood & Water  No Director Specified
# 2         s3  TV Show              Ganglands        Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans  No Director Specified
# 4         s5  TV Show           Kota Factory  No Director Specified
# ...      ...      ...                    ...                    ...
# 8802   s8803    Movie                 Zodiac          David Fincher
# 8803   s8804  TV Show            Zombie Dumb  No Director Specified
# 8804   s8805    Movie             Zombieland        Ruben Fleischer
# 8805   s8806    Movie                   Zoom           Peter Hewitt
# 8806   s8807    Movie                 Zubaan            Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %%
df["director"].value_counts()
# Out:
# No Director Specified             2634
# Rajiv Chilaka                       19
# Raúl Campos, Jan Suter              18
# Suhas Kadav                         16
# Marcus Raboy                        16
#                                   ...
# Raymie Muzquiz, Stu Livingston       1
# Joe Menendez                         1
# Eric Bross                           1
# Will Eisenberg                       1
# Mozez Singh                          1
# Name: director, Length: 4529, dtype: int64

# %% [markdown]
# # **The problem we have two directors in one row. We need to solve the problem.**

# %% [markdown]
# # **Now we have to split the 2 directory thing**

# %% [markdown]
# # **First we have to create a seperate dataset**

# %%
directors[directors["Director"]=="No Director Specified"]
# Out:
#                    Director  Total Content
# 3684  No Director Specified           2634

# %%
filtered_direcotrs=pd.DataFrame()
filtered_direcotrs=df["director"].str.split(",",expand=True).stack() #if there was no comma above in output, we wouldn't use comma in split
filtered_direcotrs=filtered_direcotrs.to_frame()
filtered_direcotrs.columns=["Director"]
directors=filtered_direcotrs.groupby(["Director"]).size().reset_index(name="Total Content")
# directors=directors[directors.Director != "No Director Specified"]

directors.head(33)
# Out:
#                        Director  Total Content
# 0                Aaron Moorhead              2
# 1                   Aaron Woolf              1
# 2      Abbas Alibhai Burmawalla              1
# 3              Abdullah Al Noor              1
# 4           Abhinav Shiv Tiwari              1
# 5              Abhishek Chaubey              2
# 6                    Abosi Ogba              1
# 7              Aco Tenriyagelli              1
# 8                  Adam Carolla              3
# 9                    Adam Darke              1
# 10          Adam Egypt Mortimer              1
# 11           Adam Larson Broder              1
# 12                     Adam Nee              1
# 13             Adam Schlesinger              1
# 14            Adirek Wattaleela              1
# 15                  Ajay Bhuyan              1
# 16            Akihiko Yamashita              1
# 17               Akiva Schaffer              2
# 18               Akshay Shankar              1
# ...

# %%
filtered_direcotrs=pd.DataFrame()
filtered_direcotrs=df["director"].str.split(",",expand=True).stack() #if there was no comma above in output, we wouldn't use comma in split
filtered_direcotrs=filtered_direcotrs.to_frame()
filtered_direcotrs.columns=["Director"]
directors=filtered_direcotrs.groupby(["Director"]).size().reset_index(name="Total Content")
directors=directors[directors.Director != "No Director Specified"]

directors=directors.sort_values(by=["Total Content"],ascending=False)

directors5=directors.head()
directorsTop5=directors5.sort_values(by=["Total Content"])
fig1=px.bar(directorsTop5,x="Total Content",y="Director",title="Top Directors on Netflix")
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
directors[directors["Director"]=="No Director Specified"]
# Out:
# Empty DataFrame
# Columns: [Director, Total Content]
# Index: []

# %%
directors.Director.value_counts()
# Out:
# Rajiv Chilaka       1
# Raúl Campos         1
# Faraz Haider        1
# Farah Nabulsi       1
#  Will Lowell        1
#                    ..
# Louise Alston       1
# Louis Leterrier     1
# Louis J. Horvitz    1
# Lucy van Beek       1
# Joaquín Mazón       1
# Name: Director, Length: 5120, dtype: int64

# %%
df
# Out:
#      show_id     type                  title               director  \
# 0         s1    Movie   Dick Johnson Is Dead        Kirsten Johnson
# 1         s2  TV Show          Blood & Water  No Director Specified
# 2         s3  TV Show              Ganglands        Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans  No Director Specified
# 4         s5  TV Show           Kota Factory  No Director Specified
# ...      ...      ...                    ...                    ...
# 8802   s8803    Movie                 Zodiac          David Fincher
# 8803   s8804  TV Show            Zombie Dumb  No Director Specified
# 8804   s8805    Movie             Zombieland        Ruben Fleischer
# 8805   s8806    Movie                   Zoom           Peter Hewitt
# 8806   s8807    Movie                 Zubaan            Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %%
df["cast"].isna().sum()
# Out:
# 825

# %%
df["cast"]=df["cast"].fillna("No cast specified")
df
# Out:
#      show_id     type                  title               director  \
# 0         s1    Movie   Dick Johnson Is Dead        Kirsten Johnson
# 1         s2  TV Show          Blood & Water  No Director Specified
# 2         s3  TV Show              Ganglands        Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans  No Director Specified
# 4         s5  TV Show           Kota Factory  No Director Specified
# ...      ...      ...                    ...                    ...
# 8802   s8803    Movie                 Zodiac          David Fincher
# 8803   s8804  TV Show            Zombie Dumb  No Director Specified
# 8804   s8805    Movie             Zombieland        Ruben Fleischer
# 8805   s8806    Movie                   Zoom           Peter Hewitt
# 8806   s8807    Movie                 Zubaan            Mozez Singh
#
#                                                    cast        country  \
# 0                                     No cast specified  United States
# ...

# %%
df["cast"].value_counts()
# Out:
# No cast specified                                                                                                                                                                             825
# David Attenborough                                                                                                                                                                             19
# Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jigna Bhardwaj, Rajesh Kava, Mousam, Swapnil                                                                                                        14
# Samuel West                                                                                                                                                                                    10
# Jeff Dunham                                                                                                                                                                                     7
# ...

# %%
filtered_cast = pd.DataFrame()
filtered_cast=df["cast"].str.split(",",expand=True).stack()
filtered_cast=filtered_cast.to_frame() #to_frame is to convert into a dataframe
filtered_cast
# Out:
#                              0
# 0    0       No cast specified
# 1    0              Ama Qamata
#      1             Khosi Ngema
#      2           Gail Mabalane
#      3          Thabang Molaba
# ...                        ...
# 8806 3        Manish Chaudhary
#      4            Meghna Malik
#      5           Malkeet Rauni
#      6          Anita Shabdish
#      7   Chittaranjan Tripathy
#
# [64951 rows x 1 columns]

# %%
filtered_cast = pd.DataFrame()
filtered_cast=df["cast"].str.split(",",expand=True).stack()
filtered_cast=filtered_cast.to_frame() #to_frame is to convert into a dataframe
filtered_cast.columns=["Cast"]
cast=filtered_cast.groupby(["Cast"]).size().reset_index(name="Total Content") #how many actors are presented 
cast=cast[cast.Cast != "No cast specified"]

cast = cast.sort_values(by=["Total Content"],ascending=False)

cast = cast.head()
cast = cast.sort_values(by=["Total Content"])
figure=px.bar(cast,x="Total Content",y="Cast",title="Top 5 actors on Netflix")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Let's analyze production over the years on Netflix:**

# %%
df1=df[["type","release_year"]]
df2=df1.groupby(["release_year","type"]).size().reset_index(name="Total Content")
df2=df2[df2["release_year"]>=2010]

fig2=px.line(df2,x="release_year",y="Total Content",color="type",title="Trend of content produced")
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Let's analyze the sentiment of content on Netflix:

# %%
dfx
# Out:
#       Release Year                                        description
# 0             2020  As her father nears the end of his life, filmm...
# 1             2021  After crossing paths at a party, a Cape Town t...
# 2             2021  To protect his family from a powerful drug lor...
# 3             2021  Feuds, flirtations and toilet talk go down amo...
# 4             2021  In a city of coaching centers known to train I...
# ...            ...                                                ...
# 8802          2007  A political cartoonist, a crime reporter and a...
# 8803          2018  While living alone in a spooky town, a young g...
# 8804          2009  Looking to survive in a world taken over by zo...
# 8805          2006  Dragged from civilian life, a former superhero...
# 8806          2015  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 2 columns]

# %%
dfx=df[["release_year","description"]]
dfx=dfx.rename(columns={"release_year":"Release Year"})
#row number and each of the row
for index,row in dfx.iterrows():
  print(row)
# Out:
# Streaming output truncated to the last 5000 lines.
# description     In 1806, ambitious magician Norrell leads a re...
# Name: 7140, dtype: object
# Release Year                                                 2017
# description     The wounds of a traumatic childhood and a corr...
# Name: 7141, dtype: object
# Release Year                                                 2015
# description     After many years away, a woman returns to her ...
# Name: 7142, dtype: object
# Release Year                                                 2016
# description     Juana Inés de la Cruz, a powerful feminist nun...
# Name: 7143, dtype: object
# Release Year                                                 1997
# description     Separated at birth, a pair of identical twins ...
# Name: 7144, dtype: object
# Release Year                                                 2011
# description     In this family film, never-dull third-grader J...
# Name: 7145, dtype: object
# ...

# %%
dfx=df[["release_year","description"]]
dfx=dfx.rename(columns={"release_year":"Release Year"})
#row number and each of the row
for index,row in dfx.iterrows():
  z=row["description"]
  testimonial=TextBlob(z)
  print(testimonial)
# Out:
# Streaming output truncated to the last 5000 lines.
# Archival video and new interviews examine Mexican politics in 1994, a year marked by the rise of the EZLN and the assassination of Luis Donaldo Colosio.
# This documentary focuses on the devastating violence of the Israel-Palestine conflict and its effects on the children of Gaza.
# This intimate documentary follows a group of Syrian children refugees who narrowly escape a life of torment and integrate into a foreign land.
# Seeking answers after a life-changing incident in 2012, filmmaker Hernán Zin interviews other war reporters about the personal toll of their work.
# An old-school Brooklyn native devotes his days to caring for his adorable dog, Bruno – and making sure the neighbors show his pooch the proper respect.
# An ex-assassin tries to leave her dark past behind until a power-hungry gang targets her and her family, forcing her to summon her killer instincts.
# ...

# %%
dfx=df[["release_year","description"]]
dfx=dfx.rename(columns={"release_year":"Release Year"})
#row number and each of the row
for index,row in dfx.iterrows():
  z=row["description"]
  testimonial=TextBlob(z)
  p=testimonial.sentiment.polarity
  if p==0:
    sent="Neutral"
  elif p>0:
    sent="Positive"
  else:
    sent="Negative"
  dfx.loc[[index,2],"Sentiment"]=sent

dfx
# Out:
#       Release Year                                        description  \
# 0             2020  As her father nears the end of his life, filmm...
# 1             2021  After crossing paths at a party, a Cape Town t...
# 2             2021  To protect his family from a powerful drug lor...
# 3             2021  Feuds, flirtations and toilet talk go down amo...
# 4             2021  In a city of coaching centers known to train I...
# ...            ...                                                ...
# 8802          2007  A political cartoonist, a crime reporter and a...
# 8803          2018  While living alone in a spooky town, a young g...
# 8804          2009  Looking to survive in a world taken over by zo...
# 8805          2006  Dragged from civilian life, a former superhero...
# 8806          2015  A scrappy but poor boy worms his way into a ty...
#
#      Sentiment
# 0     Positive
# 1      Neutral
# 2     Negative
# 3     Negative
# 4      Neutral
# ...        ...
# ...

# %%
dfx=df[["release_year","description"]]
dfx=dfx.rename(columns={"release_year":"Release Year"})
#row number and each of the row
for index,row in dfx.iterrows():
  z=row["description"]
  testimonial=TextBlob(z)
  p=testimonial.sentiment.polarity
  if p==0:
    sent="Neutral"
  elif p>0:
    sent="Positive"
  else:
    sent="Negative"
  dfx.loc[[index,2],"Sentiment"]=sent

dfx=dfx.groupby(["Release Year","Sentiment"]).size().reset_index(name="Total Content")
dfx=dfx[dfx["Release Year"]>=2010]

fig4=px.bar(dfx,x="Release Year",y="Total Content",color="Sentiment",title="Sentiment of content Analysis")
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df
# Out:
#      show_id     type                  title               director  \
# 0         s1    Movie   Dick Johnson Is Dead        Kirsten Johnson
# 1         s2  TV Show          Blood & Water  No Director Specified
# 2         s3  TV Show              Ganglands        Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans  No Director Specified
# 4         s5  TV Show           Kota Factory  No Director Specified
# ...      ...      ...                    ...                    ...
# 8802   s8803    Movie                 Zodiac          David Fincher
# 8803   s8804  TV Show            Zombie Dumb  No Director Specified
# 8804   s8805    Movie             Zombieland        Ruben Fleischer
# 8805   s8806    Movie                   Zoom           Peter Hewitt
# 8806   s8807    Movie                 Zubaan            Mozez Singh
#
#                                                    cast        country  \
# 0                                     No cast specified  United States
# ...
